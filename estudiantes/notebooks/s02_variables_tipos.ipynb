# %% [markdown]
# # Sesión 2: Variables y Tipos de Datos 📦
#
# **Curso:** Estud-IA Programación G57
# **Docente:** Eldigardo Camacho
# **Duración:** ~3 horas

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/heldigard/estudia-programacion-g57/blob/master/estudiantes/notebooks/s02_variables_tipos.ipynb)

# %% [markdown]
# ---
# ## ✅ Checklist de Apertura
#
# Antes de empezar, verifica:
# - [ ] Abrí Google Colab
# - [ ] Puedo ejecutar una celda (Shift+Enter)
# - [ ] Sé guardar una copia en Drive
# - [ ] Recuerdo cómo usar `print()` de la sesión anterior

# %% [markdown]
# ---
# ## 🎯 Objetivos de la Sesión
#
# Al final de esta sesión, podrás:
# 1. Crear y usar **variables** para guardar información
# 2. Distinguir los 3 tipos de datos básicos: `int`, `float`, `str`
# 3. Usar **`input()`** para pedir datos al usuario
# 4. **Convertir** entre tipos de datos (`int()`, `float()`, `str()`)
# 5. Usar **f-strings** para formatear texto

# %% [markdown]
# ---
# ## 📚 Conceptos Clave
#
# ### ¿Qué es una Variable?
# Una variable es como una **cajita con nombre** donde guardas información. Puedes:
# - Guardar un valor
# - Usar ese valor después
# - Cambiar el valor cuando quieras
#
# ### Los 3 Tipos de Datos Básicos
# | Tipo | Qué guarda | Ejemplo |
# |------|------------|--------|
# | `int` | Números enteros | `42`, `-5`, `0` |
# | `float` | Números decimales | `3.14`, `0.5`, `-2.7` |
# | `str` | Texto (strings) | `"Hola"`, `'Python'` |
#
# ### Reglas para Nombres de Variables
# - ✅ Usa letras, números y guión bajo: `mi_variable`, `edad2`
# - ❌ No empieces con número: ~~`2nombre`~~
# - ❌ No uses espacios: ~~`mi variable`~~
# - ❌ No uses caracteres especiales: ~~`mi-variable`~~, ~~`mi@variable`~~

# %% [markdown]
# ---
# ## 🎬 Ejemplo Guiado: Creando Variables
#
# ### Paso 1: Tu primera variable

# %%
# Crear una variable es simple: nombre = valor
nombre = "Ana"
print(nombre)

# Puedes cambiar el valor en cualquier momento
nombre = "Carlos"
print(nombre)

# %% [markdown]
# ### Paso 2: Los 3 tipos de datos

# %%
# int - número entero
edad = 25
print("Edad:", edad)
print("Tipo:", type(edad))

print()  # Línea en blanco

# float - número decimal
precio = 99.99
print("Precio:", precio)
print("Tipo:", type(precio))

print()

# str - texto (string)
ciudad = "Bogotá"
print("Ciudad:", ciudad)
print("Tipo:", type(ciudad))

# %% [markdown]
# ### Paso 3: La función `input()` - Pedir datos al usuario

# %%
# input() muestra un mensaje y espera que escribas algo
nombre = input("¿Cuál es tu nombre? ")
print("¡Hola,", nombre + "!")

# %% [markdown]
# ### ⚠️ ¡IMPORTANTE! `input()` siempre devuelve texto

# %%
# Aunque escribas un número, input() lo guarda como texto
edad = input("¿Cuántos años tienes? ")
print("Escribiste:", edad)
print("El tipo es:", type(edad))  # <-- Será 'str', no 'int'

# %% [markdown]
# ### Paso 4: Convertir tipos de datos

# %%
# Para hacer matemáticas, necesitas convertir el texto a número

# int() convierte a número entero
edad_texto = "25"
edad_numero = int(edad_texto)
print("Tipo original:", type(edad_texto))
print("Tipo convertido:", type(edad_numero))

print()

# float() convierte a número decimal
precio_texto = "99.99"
precio_numero = float(precio_texto)
print("Precio como número:", precio_numero)

print()

# str() convierte a texto
numero = 42
texto = str(numero)
print("Ahora es texto:", texto, "- Tipo:", type(texto))

# %% [markdown]
# ### Paso 5: F-strings - La forma más fácil de formatear texto

# %%
# Los f-strings empiezan con f"..." y permiten incluir variables con {}
nombre = "María"
edad = 28
ciudad = "Medellín"

# Sin f-string (complicado)
print("Hola, " + nombre + ". Tienes " + str(edad) + " años y vives en " + ciudad + ".")

# Con f-string (¡mucho más fácil!)
print(f"Hola, {nombre}. Tienes {edad} años y vives en {ciudad}.")

# %% [markdown]
# ---
# ## ⭐ Actividad Estrella: Calculadora de Edad
#
# Vamos a crear un programa que pide tu año de nacimiento y calcula tu edad.

# %%
# === CALCULADORA DE EDAD ===

# Pedir datos al usuario
nombre = input("¿Cómo te llamas? ")
anio_nacimiento = input("¿En qué año naciste? ")

# Convertir el año a número
anio_nacimiento = int(anio_nacimiento)

# Calcular edad
anio_actual = 2026
edad = anio_actual - anio_nacimiento

# Mostrar resultado con f-string
print(f"\n¡Hola, {nombre}!")
print(f"Si naciste en {anio_nacimiento}, tienes aproximadamente {edad} años.")

# %% [markdown]
# ---
# ## 💪 Ejercicios
#
# ### Nivel A: Guiado (Sigue los pasos)

# %% [markdown]
# **Ejercicio A1:** Crea 3 variables y muéstralas

# %%
# Crea las siguientes variables:
# 1. mi_nombre (str) - tu nombre
# 2. mi_edad (int) - tu edad
# 3. mi_altura (float) - tu altura en metros (ej: 1.75)

# Tu código aquí:
mi_nombre = ???
mi_edad = ???
mi_altura = ???

# Muestra los valores y sus tipos
print("Nombre:", mi_nombre, "- Tipo:", type(mi_nombre))
print("Edad:", mi_edad, "- Tipo:", type(mi_edad))
print("Altura:", mi_altura, "- Tipo:", type(mi_altura))

# %% [markdown]
# **Ejercicio A2:** Pide un número y multiplícalo por 2

# %%
# 1. Pide un número con input()
numero_texto = input("Escribe un número: ")

# 2. Conviértelo a int
numero = ???  # Completa aquí

# 3. Calcula el doble
doble = ???  # Completa aquí

# 4. Muestra el resultado
print(f"El doble de {numero} es {doble}")

# %% [markdown]
# **Ejercicio A3:** Reescribe usando f-strings

# %%
# Variables ya definidas
producto = "Laptop"
precio = 2500000
descuento = 10

# Esta línea usa concatenación (complicada):
print("Producto: " + producto + " - Precio: $" + str(precio) + " - Descuento: " + str(descuento) + "%")

# Reescríbela usando f-string (más simple):
print(???)  # Tu código aquí

# %% [markdown]
# ### Nivel B: Independiente (Más práctica)

# %% [markdown]
# **Ejercicio B1:** Conversor de temperatura (Celsius a Fahrenheit)
#
# Fórmula: `F = C * 9/5 + 32`

# %%
# 1. Pide la temperatura en Celsius
# 2. Convierte a número
# 3. Calcula Fahrenheit
# 4. Muestra con f-string: "X°C equivale a Y°F"

# Tu código aquí:

# %% [markdown]
# **Ejercicio B2:** Calculadora de IMC (Índice de Masa Corporal)
#
# Fórmula: `IMC = peso / (altura ** 2)`

# %%
# 1. Pide el peso en kg
# 2. Pide la altura en metros
# 3. Calcula el IMC
# 4. Muestra: "Tu IMC es: X"

# Tu código aquí:

# %% [markdown]
# **Ejercicio B3:** Ficha de registro de estudiante

# %%
# Pide los siguientes datos:
# - Nombre completo
# - Edad
# - Carrera o programa
# - Promedio actual (número decimal)

# Luego muestra una "ficha" formateada así:
# ===== FICHA DE ESTUDIANTE =====
# Nombre: [nombre]
# Edad: [edad] años
# Programa: [carrera]
# Promedio: [promedio]
# ================================

# Tu código aquí:

# %% [markdown]
# ### Nivel C: Reto Opcional 🌟

# %% [markdown]
# **Ejercicio C1:** Calculadora de tiempo de viaje
#
# Pide la distancia en km y la velocidad promedio en km/h. Calcula el tiempo de viaje en horas y minutos.

# %%
# Ejemplo de salida esperada:
# "Para recorrer 150 km a 60 km/h, necesitas 2 horas y 30 minutos."

# Pistas:
# - tiempo_horas = distancia / velocidad
# - horas_enteras = int(tiempo_horas)  (parte entera)
# - minutos = (tiempo_horas - horas_enteras) * 60

# Tu código aquí:

# %% [markdown]
# ---
# ## ⚠️ Errores Comunes (y cómo arreglarlos)
#
# ### Error 1: Intentar hacer matemáticas con texto

# %%
# ❌ INCORRECTO - Esto suma texto, no números
numero1 = "5"
numero2 = "3"
print(numero1 + numero2)  # Resultado: "53" (concatenación)

# ✅ CORRECTO - Convertir a int primero
numero1 = int("5")
numero2 = int("3")
print(numero1 + numero2)  # Resultado: 8 (suma)

# %% [markdown]
# ### Error 2: Olvidar convertir el input a número

# %%
# ❌ INCORRECTO - edad es string, no puedes sumarle 1
# edad = input("Tu edad: ")
# print(edad + 1)  # TypeError!

# ✅ CORRECTO
edad = int(input("Tu edad: "))
print(f"El próximo año tendrás {edad + 1} años")

# %% [markdown]
# ### Error 3: Nombre de variable inválido

# %%
# ❌ INCORRECTO
# 2nombre = "Ana"      # No puede empezar con número
# mi-edad = 25         # No puede tener guión
# mi edad = 25         # No puede tener espacios

# ✅ CORRECTO
nombre2 = "Ana"
mi_edad = 25
miEdad = 25  # También válido (camelCase)

# %% [markdown]
# ---
# ## 📝 Mini-Quiz de Cierre
#
# **1.** ¿Qué tipo de dato es `"42"`?
# - a) int
# - b) float
# - c) str
#
# **2.** ¿Qué función convierte texto a número entero?
# - a) `str()`
# - b) `int()`
# - c) `float()`
#
# **3.** ¿Qué imprime este código?
# ```python
# x = input("Número: ")  # El usuario escribe: 10
# print(type(x))
# ```
# - a) `<class 'int'>`
# - b) `<class 'str'>`
# - c) `<class 'float'>`
#
# **4.** ¿Cuál es la forma correcta de crear un f-string?
# - a) `print("Hola {nombre}")`
# - b) `print(f"Hola {nombre}")`
# - c) `print("Hola" + {nombre})`
#
# **5.** ¿Cuál de estos nombres de variable es INVÁLIDO?
# - a) `mi_variable`
# - b) `variable2`
# - c) `2variable`

# %% [markdown]
# <details>
# <summary>👀 Ver respuestas</summary>
#
# 1. **c) str** - Todo lo que está entre comillas es texto
# 2. **b) int()** - Convierte a entero
# 3. **b) `<class 'str'>`** - input() siempre devuelve string
# 4. **b) `print(f"Hola {nombre}")`** - La f al inicio es clave
# 5. **c) `2variable`** - No puede empezar con número
#
# </details>

# %% [markdown]
# ---
# ## 🎯 Resumen de la Sesión
#
# Hoy aprendiste:
# 1. **Variables** guardan información: `nombre = "valor"`
# 2. **3 tipos básicos**: `int` (enteros), `float` (decimales), `str` (texto)
# 3. **`input()`** pide datos al usuario (siempre devuelve `str`)
# 4. **Conversiones**: `int()`, `float()`, `str()`
# 5. **F-strings**: `f"Hola, {variable}"`
#
# ---
#
# ## ➡️ Próxima Sesión
# **Sesión 3: Operadores y Expresiones**
#
# Aprenderás más operadores matemáticos, comparaciones, y cómo combinar expresiones.
#
# ---
# *¿Dudas? ¡Pregunta ahora!* 🙋
