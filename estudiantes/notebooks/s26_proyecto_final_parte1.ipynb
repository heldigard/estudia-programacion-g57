# %% [markdown]
# # Sesión 26: Proyecto Final - Parte 1 🚀
#
# **Curso:** Estud-IA Programación G57
# **Docente:** Eldigardo Camacho
# **Duración:** ~4 horas
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/heldigard/estudia-programacion-g57/blob/master/estudiantes/notebooks/s26_proyecto_final_parte1.ipynb)

# %% [markdown]
# ---
# ## ✅ Checklist de Apertura
#
# Antes de empezar, verifica:
# - [ ] Abrí Google Colab
# - [ ] Conozco cómo ejecutar celdas (Shift+Enter)
# - [ ] Tengo el notebook guardado en Drive
# - [ ] Revisé las 4 opciones del proyecto final
# - [ ] Tengo una idea de qué proyecto quiero desarrollar

# %% [markdown]
# ---
# ## 🎯 Objetivos de la Sesión
#
# Al final de esta sesión, podrás:
# 1. Seleccionar una opción de proyecto final
# 2. Diseñar la arquitectura de tu sistema
# 3. Crear las funciones principales
# 4. Implementar el manejo básico de archivos
# 5. Tener un menú funcional inicial
# 6. **Usar clases** para organizar tu código

# %% [markdown]
# ## 🆕 Requisito: Usar Clases en tu Proyecto
#
# Tu proyecto final debe incluir **al menos 2 clases** para organizar tu código.

# %% [markdown]
# ### ¿Por qué usar clases en tu proyecto?
#
# - **Organización:** Código más limpio y ordenado
# - **Reutilización:** Métodos que puedes usar muchas veces
# - **Escalabilidad:** Fácil agregar nuevas funciones
# - **Buenas prácticas:** Así se hace código profesional

# %% [markdown]
# ### Ejemplo: Proyecto de Inventario
#
# ```python
# class Producto:
#     def __init__(self, nombre, precio, stock):
#         self.nombre = nombre
#         self.precio = precio
#         self.stock = stock
#
#     def valor_total(self):
#         return self.precio * self.stock
#
# class Inventario:
#     def __init__(self):
#         self.productos = []
#
#     def agregar(self, producto):
#         self.productos.append(producto)
#
#     def valor_total(self):
#         return sum(p.valor_total() for p in self.productos)
# ```

# %% [markdown]
# ### Requisitos Mínimos
#
# 1. **Al menos 2 clases** con `__init__` y atributos
# 2. **Métodos** útiles (no solo `__init__`)
# 3. **Validaciones** en `__init__` para proteger datos
# 4. **Usar objetos** en listas o procesamiento de archivos

# %% [markdown]
# ---
# ## 🏁 Proyecto Final: ¡Tu Momento de Brillar!
#
# Después de semanas aprendiendo Python, ahora es el momento de aplicar **todo** lo aprendido en un proyecto real.
#
# ### ¿Qué debes entregar?
# - **Un sistema integrado** con menú interactivo
# - **Funciones** con return y docstrings
# - **Archivos** CSV y TXT
# - **Validaciones** de entrada del usuario
# - **Código** limpio, organizado y funcional
#
# ### Peso en la nota final: 30%
# ### Tiempo total: 2 sesiones (26 y 27)

# %% [markdown]
# ---
# ## 📋 Revisión de Opciones
#
# Lee cada opción y piensa cuál te gustaría desarrollar:

# %% [markdown]
# ### Opción A: Gestor de Gastos Personales 💰
#
# **Descripción:** Sistema para registrar, categorizar y analizar gastos.
#
# **Funcionalidades principales:**
# 1. Registro de gastos (fecha, descripción, monto, categoría)
# 2. Categorías predefinidas + personalizadas
# 3. Almacenamiento en CSV
# 4. Reportes: total mensual, por categoría, promedio diario
# 5. Menú interactivo con opciones básicas
#
# **Tecnologías:** funciones, archivos CSV, diccionarios, listas

# %% [markdown]
# ### Opción B: Sistema de Inventario 📦
#
# **Descripción:** Sistema para gestionar inventario de una tienda.
#
# **Funcionalidades principales:**
# 1. CRUD de productos (código, nombre, cantidad, precio)
# 2. Alertas de stock bajo
# 3. Registro de entradas/salidas
# 4. Reportes: valor total, productos por categoría
# 5. Backup de datos
#
# **Tecnologías:** funciones, archivos CSV/TXT, listas de diccionarios

# %% [markdown]
# ### Opción C: Registro de Estudiantes y Notas 📚
#
# **Descripción:** Sistema para gestionar estudiantes y calificaciones.
#
# **Funcionalidades principales:**
# 1. CRUD de estudiantes (ID, nombre, email, curso)
# 2. Registro de notas por materia
# 3. Cálculo de promedios
# 4. Reportes: estudiantes por curso, promedios, aprobados/reprobados
# 5. Exportar boletín individual
#
# **Tecnologías:** funciones, archivos CSV, cálculos matemáticos

# %% [markdown]
# ### Opción D: Mini-Asistente por Consola 🤖
#
# **Descripción:** Asistente interactivo con múltiples utilidades.
#
# **Funcionalidades principales:**
# 1. Calculadora avanzada (operaciones, porcentajes, conversiones)
# 2. Gestor de tareas (CRUD con archivos)
# 3. Generador de contraseñas configurables
# 4. Juego de adivinanza con pistas
# 5. Menú principal unificado
#
# **Tecnologías:** funciones, módulos (random, math), archivos

# %% [markdown]
# ### Opción E: Organizador de Entretenimiento 🎬🎮 *(Nueva 2026)*
#
# **Descripción:** Sistema para gestionar tu biblioteca personal de series, películas, videojuegos o libros.
#
# **Funcionalidades principales:**
# 1. Gestión de contenido (título, tipo, género, plataforma, estado, rating)
# 2. Sistema de recomendaciones ("¿Qué veo/juego hoy?")
# 3. Almacenamiento en CSV con historial
# 4. Estadísticas: géneros favoritos, rating promedio, top 5
# 5. Menú interactivo con filtros
#
# **Tecnologías:** funciones, archivos CSV, módulo random, listas de diccionarios
#
# **¿Para quién es ideal?** Amantes del cine, series, videojuegos o lectura que quieran organizar su contenido.

# %% [markdown]
# ### Opción F: Bot Analizador de Hábitos 📊🤖 *(Nueva 2026)*
#
# **Descripción:** Asistente personal para registrar y analizar hábitos diarios (ejercicio, sueño, agua, lectura, etc.).
#
# **Funcionalidades principales:**
# 1. Registro de hábitos diarios con fecha automática
# 2. Seguimiento de rachas (streaks) y metas
# 3. Análisis de patrones (mejor día, peor día)
# 4. Almacenamiento en CSV con historial
# 5. Gráficos ASCII de progreso semanal
#
# **Tecnologías:** funciones, archivos CSV, datetime, listas, estadísticas básicas
#
# **¿Para quién es ideal?** Personas que quieran construir buenos hábitos y ver su progreso.

# %%
# EJERCICIO: Selecciona tu proyecto
# Cambia el valor de la variable 'opcion_elegida' a 'A', 'B', 'C', 'D', 'E' o 'F'

opcion_elegida = ""  # Ejemplo: opcion_elegida = "A"

proyectos = {
    "A": "Gestor de Gastos Personales 💰",
    "B": "Sistema de Inventario 📦",
    "C": "Registro de Estudiantes y Notas 📚",
    "D": "Mini-Asistente por Consola 🤖",
    "E": "Organizador de Entretenimiento 🎬🎮 (Nueva 2026)",
    "F": "Bot Analizador de Hábitos 📊🤖 (Nueva 2026)"
}

if opcion_elegida.upper() in proyectos:
    print(f"✅ Has seleccionado: {proyectos[opcion_elegida.upper()]}")
else:
    print("❌ Por favor selecciona una opción válida (A, B, C, D, E o F)")
    print("\n📋 Opciones disponibles:")
    for letra, nombre in proyectos.items():
        print(f"   {letra}: {nombre}")

# %% [markdown]
# ---
# ## 🏗️ Paso 1: Diseño de la Arquitectura
#
# **Regla de oro:** *"Planifica antes de codear"*
#
# ### Elementos clave a diseñar:
# 1. **Estructura de datos:** ¿Cómo guardarás la información?
# 2. **Funciones principales:** ¿Qué hará cada función?
# 3. **Archivos:** ¿Qué datos guardarás en CSV/TXT?
# 4. **Menú:** ¿Qué opciones tendrá el usuario?

# %% [markdown]
# ### Ejemplo: Estructura para Gestor de Gastos
#
# ```python
# # Lista de diccionarios para gastos
# gastos = [
#     {
#         "fecha": "2024-01-15",
#         "descripcion": "Supermercado",
#         "monto": 85000,
#         "categoria": "Alimentación"
#     },
#     {
#         "fecha": "2024-01-16",
#         "monto": 15000,
#         "descripcion": "Transporte",
#         "categoria": "Transporte"
#     }
# ]
# ```
#
# **Preguntas para tu diseño:**
# 1. ¿Qué información guardará cada elemento?
# 2. ¿Cómo se relacionan los datos?
# 3. ¿Qué estructura es más conveniente (lista, diccionario, etc.)?

# %% [markdown]
# ### Paso 2: Diseño de Funciones
#
# Cada función debe hacer **una sola cosa** y tener:
# - Nombre descriptivo
# - Parámetros claros
# - Valor de retorno útil
# - Docstring explicativo
#
# **Ejemplo de diseño:**
# ```python
# def agregar_gasto(gastos, fecha, descripcion, monto, categoria):
#     '''
#     Agrega un nuevo gasto a la lista.
#
#     Parámetros:
#     - gastos: lista de gastos existentes
#     - fecha: fecha del gasto (YYYY-MM-DD)
#     - descripcion: descripción del gasto
#     - monto: valor numérico del gasto
#     - categoria: categoría del gasto
#
#     Retorna:
#     - La lista de gastos actualizada
#     '''
#     # Implementación aquí
#     return gastos
# ```

# %%
# EJERCICIO: Diseña tus funciones
# Escribe al menos 3 funciones que necesitarás en tu proyecto
# Usa el formato de docstring como ejemplo

# Función 1: 
def funcion_1(parametro1, parametro2):
    '''
    Descripción breve de la función.
    
    Parámetros:
    - parametro1: descripción
    - parametro2: descripción
    
    Retorna:
    - qué retorna
    '''
    # Tu código aquí
    pass

# Función 2:
def funcion_2(parametro1):
    '''
    Descripción breve.
    '''
    pass

# Función 3:
def funcion_3():
    '''
    Descripción breve.
    '''
    pass

# %% [markdown]
# ---
# ## 💾 Paso 3: Manejo de Archivos
#
# Tu proyecto debe usar al menos:
# - **Un archivo CSV** para datos principales
# - **Un archivo TXT** para logs o reportes
#
# ### Patrón recomendado:
# 1. **Al iniciar:** Cargar datos desde CSV si existe
# 2. **Durante ejecución:** Trabajar con datos en memoria
# 3. **Al salir/guardar:** Escribir datos actualizados a CSV

# %%
# Ejemplo: Cargar gastos desde CSV
import csv

def cargar_gastos_desde_csv(archivo_csv):
    '''Carga gastos desde un archivo CSV.'''
    gastos = []
    try:
        with open(archivo_csv, 'r', newline='', encoding='utf-8') as archivo:
            lector = csv.DictReader(archivo)
            for fila in lector:
                gastos.append(fila)
        print(f"✅ Cargados {len(gastos)} gastos desde {archivo_csv}")
    except FileNotFoundError:
        print(f"📄 Archivo {archivo_csv} no encontrado. Se creará uno nuevo.")
    return gastos

# Ejemplo de uso
gastos = cargar_gastos_desde_csv("gastos.csv")
print(f"Total de gastos en memoria: {len(gastos)}")

# %%
# Ejemplo: Guardar gastos a CSV
import csv

def guardar_gastos_a_csv(gastos, archivo_csv):
    '''Guarda gastos a un archivo CSV.'''
    if not gastos:
        print("⚠️  No hay gastos para guardar.")
        return
    
    # Definir nombres de columnas
    campos = ["fecha", "descripcion", "monto", "categoria"]
    
    try:
        with open(archivo_csv, 'w', newline='', encoding='utf-8') as archivo:
            escritor = csv.DictWriter(archivo, fieldnames=campos)
            escritor.writeheader()
            escritor.writerows(gastos)
        print(f"💾 Gastos guardados en {archivo_csv}")
    except Exception as e:
        print(f"❌ Error al guardar: {e}")

# Ejemplo de uso
gastos_ejemplo = [
    {"fecha": "2024-01-15", "descripcion": "Supermercado", "monto": "85000", "categoria": "Alimentación"},
    {"fecha": "2024-01-16", "descripcion": "Transporte", "monto": "15000", "categoria": "Transporte"}
]

guardar_gastos_a_csv(gastos_ejemplo, "gastos_ejemplo.csv")

# %% [markdown]
# ---
# ## 📋 Paso 4: Diseño del Menú
#
# El menú es la **interfaz principal** con el usuario. Debe ser:
# - Claro y fácil de entender
# - Con opciones numeradas
# - Con validación de entrada
# - Con opción de salida
#
# ### Estructura típica:
# ```python
# while True:
#     mostrar_menu()
#     opcion = input("Selecciona una opción: ")
#
#     if opcion == "1":
#         agregar_dato()
#     elif opcion == "2":
#         ver_datos()
#     elif opcion == "3":
#         generar_reporte()
#     elif opcion == "4":
#         guardar_y_salir()
#         break
#     else:
#         print("Opción inválida")
# ```

# %%
# EJERCICIO: Crea tu menú básico
# Completa este esquema con las opciones de tu proyecto

def mostrar_menu():
    '''Muestra las opciones del menú principal.'''
    print("\n" + "="*50)
    print("MENÚ PRINCIPAL")
    print("="*50)
    print("1. [Tu primera opción]")
    print("2. [Tu segunda opción]")
    print("3. [Tu tercera opción]")
    print("4. Guardar y salir")
    print("="*50)

def main():
    '''Función principal que ejecuta el menú.'''
    # Inicializar datos
    datos = []  # Aquí irían tus datos cargados
    
    while True:
        mostrar_menu()
        opcion = input("\nSelecciona una opción (1-4): ")
        
        if opcion == "1":
            print("Implementa la opción 1 aquí")
            # llamar_a_funcion_1(datos)
        elif opcion == "2":
            print("Implementa la opción 2 aquí")
            # llamar_a_funcion_2(datos)
        elif opcion == "3":
            print("Implementa la opción 3 aquí")
            # llamar_a_funcion_3(datos)
        elif opcion == "4":
            print("💾 Guardando datos...")
            # guardar_datos(datos)
            print("👋 ¡Hasta pronto!")
            break
        else:
            print("❌ Opción inválida. Intenta de nuevo.")

# Para ejecutar el menú, descomenta la siguiente línea:
# main()

# %% [markdown]
# ---
# ## 🧠 Taller Guiado: Implementación Inicial
#
# Vamos a construir juntos los primeros componentes de un Gestor de Gastos (Opción A). Puedes adaptar estos conceptos a tu proyecto.

# %%
# CÓDIGO BASE - Gestor de Gastos
# Puedes usar este código como punto de partida

import csv
import os

# Constantes
ARCHIVO_GASTOS = "gastos.csv"
CATEGORIAS = ["Alimentación", "Transporte", "Entretenimiento", "Servicios", "Otros"]

def cargar_gastos():
    '''Carga gastos desde archivo CSV.'''
    gastos = []
    if os.path.exists(ARCHIVO_GASTOS):
        with open(ARCHIVO_GASTOS, 'r', newline='', encoding='utf-8') as archivo:
            lector = csv.DictReader(archivo)
            for fila in lector:
                gastos.append(fila)
        print(f"✅ Cargados {len(gastos)} gastos")
    else:
        print("📄 No hay archivo de gastos. Se creará uno nuevo.")
    return gastos

def mostrar_gastos(gastos):
    '''Muestra todos los gastos registrados.'''
    if not gastos:
        print("📭 No hay gastos registrados.")
        return
    
    print("\n📋 GASTOS REGISTRADOS:")
    print("-" * 60)
    total = 0
    for i, gasto in enumerate(gastos, 1):
        print(f"{i}. {gasto['fecha']} - {gasto['descripcion']} - ${gasto['monto']} - {gasto['categoria']}")
        total += float(gasto['monto'])
    print("-" * 60)
    print(f"💰 TOTAL: ${total:.0f}")

# Ejemplo de uso
gastos = cargar_gastos()
mostrar_gastos(gastos)

# %% [markdown]
# ### Ejercicio: Extiende el Código Base
#
# Agrega al menos una de estas funcionalidades:
# 1. Función `agregar_gasto()` que pida datos al usuario
# 2. Función `guardar_gastos()` que guarde en CSV
# 3. Función `calcular_total_por_categoria()`
#
# **Recuerda:** Cada función debe tener docstring y manejar errores.

# %% [markdown]
# ---
# ## 💪 Ejercicios Independientes
#
# ### Nivel A: Diseño básico

# %%
# Ejercicio A1: Completa el diseño

# Para tu proyecto elegido, define:
# 1. Estructura de datos principal (lista/diccionario)
# 2. Nombres de 5 funciones clave
# 3. Nombre del archivo CSV principal
# 4. 3 reportes que generarás

# Escribe tus respuestas como comentarios:
# 1. Estructura: 
# 2. Funciones: 
# 3. Archivo CSV: 
# 4. Reportes:

# %% [markdown]
# ### Nivel B: Implementación inicial

# %%
# Ejercicio B1: Implementa 2 funciones básicas

# Para tu proyecto, implementa DOS funciones:
# 1. Una función que cargue datos desde CSV
# 2. Una función que muestre los datos en pantalla

# Función 1: Cargar datos
def cargar_datos(archivo_csv):
    '''Carga datos desde archivo CSV.'''
    datos = []
    # Implementa aquí
    return datos

# Función 2: Mostrar datos
def mostrar_datos(datos):
    '''Muestra datos en pantalla.'''
    # Implementa aquí
    pass

# Test básico
print("🔧 Probando funciones...")
datos_prueba = cargar_datos("prueba.csv")
mostrar_datos(datos_prueba)

# %% [markdown]
# ### Nivel C: Menú interactivo

# %%
# Ejercicio C1: Crea un menú funcional

# Implementa un menú con al menos 3 opciones:
# 1. Ver datos
# 2. Agregar nuevo dato
# 3. Salir

# Puedes usar este esqueleto:
def menu_principal():
    datos = []  # Aquí cargarías datos reales
    
    while True:
        print("\n=== MENÚ PRINCIPAL ===")
        print("1. Ver datos")
        print("2. Agregar nuevo dato")
        print("3. Salir")
        
        opcion = input("Selecciona opción: ")
        
        if opcion == "1":
            print("Mostrando datos...")
            # mostrar_datos(datos)
        elif opcion == "2":
            print("Agregando dato...")
            # agregar_dato(datos)
        elif opcion == "3":
            print("¡Hasta pronto!")
            break
        else:
            print("Opción inválida")

# Para ejecutar, descomenta:
# menu_principal()

# %% [markdown]
# ---
# ## 🕒 Actividad Extra (60 minutos)
#
# ### Proyecto: Prototipo Funcional
#
# Crea un prototipo funcional de tu proyecto con:
# 1. **Al menos 3 funciones** implementadas
# 2. **Carga/guardado** en CSV
# 3. **Menú básico** funcional
# 4. **Validaciones** de entrada
# 5. **Manejo de errores** con try-except
#
# **Objetivo:** Al final de la sesión 26, debes tener la estructura básica funcionando. La sesión 27 será para completar funcionalidades y pulir detalles.

# %%
# ESPACIO PARA TU PROTOTIPO
# Implementa aquí tu prototipo funcional

print("🚀 ¡Comienza a codear tu proyecto!")
print("Recuerda seguir estos pasos:")
print("1. Diseñar estructura de datos")
print("2. Implementar funciones básicas")
print("3. Crear menú interactivo")
print("4. Probar y corregir errores")

# %% [markdown]
# ---
# ## ✅ Checklist de la Sesión 26
#
# Antes de terminar, verifica que tienes:
# - [ ] Opción de proyecto seleccionada
# - [ ] Diseño de estructura de datos
# - [ ] Diseño de al menos 5 funciones
# - [ ] Esquema de archivos CSV/TXT
# - [ ] Diseño del menú principal
# - [ ] Prototipo con funciones básicas implementadas
# - [ ] Código guardado en Drive
#
# **Consejo:** Si terminas temprano, comienza a implementar más funciones o mejora las existentes.

# %% [markdown]
# ---
# ## ➡️ Próxima Sesión
# **Sesión 27: Proyecto Final - Parte 2 (Finalización)**
#
# En la próxima sesión:
# 1. Completarás todas las funcionalidades
# 2. Implementarás reportes y análisis
# 3. Mejorarás la interfaz de usuario
# 4. Probarás y corregirás errores
# 5. Prepararás la entrega final
#
# ---
# *¿Dudas? ¡Esta es tu oportunidad de demostrar todo lo aprendido! Pide ayuda si la necesitas.* 🙋
