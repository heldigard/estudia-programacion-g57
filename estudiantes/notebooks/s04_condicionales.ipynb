# %% [markdown]
# # Sesión 4: Condicionales (if/elif/else) 🚦
#
# **Curso:** Estud-IA Programación G57
# **Docente:** Eldigardo Camacho
# **Duración:** ~3 horas

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/heldigard/estudia-programacion-g57/blob/master/estudiantes/notebooks/s04_condicionales.ipynb)

# %% [markdown]
# ---
# ## ✅ Checklist de Apertura
#
# Antes de empezar, verifica:
# - [ ] Recuerdo los operadores de comparación: `==`, `!=`, `>`, `<`, `>=`, `<=`
# - [ ] Recuerdo los operadores lógicos: `and`, `or`, `not`
# - [ ] Sé que las comparaciones devuelven `True` o `False`

# %% [markdown]
# ---
# ## 🎯 Objetivos de la Sesión
#
# Al final de esta sesión, podrás:
# 1. Usar **`if`** para ejecutar código solo si una condición es verdadera
# 2. Usar **`else`** para ejecutar código cuando la condición es falsa
# 3. Usar **`elif`** para verificar múltiples condiciones
# 4. **Anidar** condicionales (if dentro de if)
# 5. Combinar condiciones con **`and`**, **`or`**, **`not`**

# %% [markdown]
# ---
# ## 📚 Conceptos Clave
#
# ### ¿Qué son los Condicionales?
# Los condicionales permiten que tu programa **tome decisiones**. Es como un semáforo:
# - 🟢 Si la luz es verde → avanza
# - 🔴 Si la luz es roja → detente
#
# ### Sintaxis Básica
# ```python
# if condición:
#     # código que se ejecuta si la condición es True
# ```
#
# **⚠️ IMPORTANTE:** El código dentro del `if` debe estar **indentado** (4 espacios o 1 Tab)

# %% [markdown]
# ---
# ## 🎬 Ejemplo Guiado: Tu Primer if
#
# ### Paso 1: El if más simple

# %%
edad = 18

if edad >= 18:
    print("Eres mayor de edad")
    print("Puedes votar")

# %%
# ¿Qué pasa si la condición es falsa?
edad = 15

if edad >= 18:
    print("Eres mayor de edad")  # Esto NO se ejecuta

print("Este mensaje siempre aparece")  # Esto SÍ se ejecuta (está fuera del if)

# %% [markdown]
# ### Paso 2: if-else (si no...)

# %%
edad = 15

if edad >= 18:
    print("Eres mayor de edad")
    print("Puedes votar")
else:
    print("Eres menor de edad")
    print("Todavía no puedes votar")

# %% [markdown]
# ### Paso 3: if-elif-else (múltiples opciones)

# %%
nota = 85

if nota >= 90:
    print("Excelente - A")
elif nota >= 80:
    print("Muy bien - B")
elif nota >= 70:
    print("Bien - C")
elif nota >= 60:
    print("Suficiente - D")
else:
    print("Reprobado - F")

# %% [markdown]
# **💡 Tip:** Las condiciones se evalúan en orden. Cuando una es `True`, las demás se ignoran.

# %%
# Prueba con diferentes valores
nota = int(input("Ingresa tu nota (0-100): "))

if nota >= 90:
    resultado = "Excelente - A"
elif nota >= 80:
    resultado = "Muy bien - B"
elif nota >= 70:
    resultado = "Bien - C"
elif nota >= 60:
    resultado = "Suficiente - D"
else:
    resultado = "Reprobado - F"

print(f"Tu calificación: {resultado}")

# %% [markdown]
# ### Paso 4: Combinando condiciones con and, or, not

# %%
# AND: Ambas condiciones deben ser True
edad = 25
tiene_licencia = True

if edad >= 18 and tiene_licencia:
    print("Puedes conducir")
else:
    print("No puedes conducir")

# %%
# OR: Al menos una condición debe ser True
es_estudiante = True
es_profesor = False

if es_estudiante or es_profesor:
    print("Tienes acceso a la biblioteca")
else:
    print("No tienes acceso")

# %%
# NOT: Invierte la condición
esta_lloviendo = False

if not esta_lloviendo:
    print("¡Buen día para salir!")
else:
    print("Mejor quédate en casa")

# %% [markdown]
# ### Paso 5: Condicionales anidados (if dentro de if)

# %%
edad = 20
tiene_entrada = True

if edad >= 18:
    print("Eres mayor de edad")
    if tiene_entrada:
        print("¡Puedes entrar al concierto!")
    else:
        print("Necesitas comprar una entrada")
else:
    print("No puedes entrar - Solo mayores de 18")

# %% [markdown]
# ### Paso 6: Operador Ternario
#
# El operador ternario es una forma compacta de escribir un if-else en una línea.

# %%
# Forma tradicional (if-else)
edad = 18
if edad >= 18:
    mensaje1 = "Es mayor"
else:
    mensaje1 = "Es menor"

# Operador ternario (más compacto)
mensaje2 = "Es mayor" if edad >= 18 else "Es menor"

print(f"Con if-else: {mensaje1}")
print(f"Con ternario: {mensaje2}")

# Ejemplos prácticos
nota = 85
estado = "Aprobado" if nota >= 60 else "Reprobado"
print(f"
Nota {nota}: {estado}")

hora = 14
saludo = "Buenos días" if hora < 12 else "Buenas tardes"
print(f"{saludo} (son las {hora} horas)")

# %% [markdown]
# ### Paso 7: Match/Case (Python 3.10+)
#
# El `match/case` es una alternativa más legible a múltiples `if/elif` cuando comparas una variable con muchos valores.

# %%
# Ejemplo: Día de la semana
dia = 3

# Forma tradicional con if/elif
if dia == 1:
    nombre_dia1 = "Lunes"
elif dia == 2:
    nombre_dia1 = "Martes"
elif dia == 3:
    nombre_dia1 = "Miércoles"
else:
    nombre_dia1 = "Otro día"

# Forma moderna con match/case
match dia:
    case 1:
        nombre_dia2 = "Lunes"
    case 2:
        nombre_dia2 = "Martes"
    case 3:
        nombre_dia2 = "Miércoles"
    case _:
        nombre_dia2 = "Otro día"

print(f"if/elif: {nombre_dia1}")
print(f"match/case: {nombre_dia2}")

# Ejemplo con strings
estado = "aprobado"

match estado:
    case "aprobado":
        emoji = "✅"
    case "reprobado":
        emoji = "❌"
    case _:
        emoji = "❓"

print(f"
Estado {estado}: {emoji}")

# %% [markdown]
# **💡 Tip: Cortocircuito en operadores lógicos**
#
# - `or`: Devuelve el primer valor `True`, o el último si todos son `False`
# - `and`: Devuelve el primer valor `False`, o el último si todos son `True`

# %%
# Cortocircuito con OR
resultado_or = False or "Hola" or 42
print(f"False or 'Hola' or 42 = {resultado_or}")  # "Hola"

# Cortocircuito con AND
resultado_and = "Python" and 3 and True
print(f"\"Python\" and 3 and True = {resultado_and}")  # True

# Uso práctico: valores por defecto
nombre = ""  # String vacío (falsy)
nombre_mostrar = nombre or "Desconocido"
print(f"
Nombre: {nombre_mostrar}")  # "Desconocido"

nombre2 = "Ana"
nombre_mostrar2 = nombre2 or "Desconocido"
print(f"Nombre: {nombre_mostrar2}")  # "Ana"

# %% [markdown]
# ---
# ## ⭐ Actividad Estrella: Cajero Automático Básico

# %% [markdown]
# ---
# ## Actividad Extra (10-15 min): Clasificador de notas
#
# Objetivo: practicar if/elif/else y rangos.
#
# Pasos sugeridos:
# 1. Pide una nota de 0 a 100
# 2. Imprime A, B, C, D o F
# 3. Muestra un mensaje final con la categoria

# %%
# === MINI-PROYECTO: CLASIFICADOR DE NOTAS ===
nota = float(input("Nota (0-100): "))

if nota >= 90:
    categoria = "A"
elif nota >= 80:
    categoria = "B"
elif nota >= 70:
    categoria = "C"
elif nota >= 60:
    categoria = "D"
else:
    categoria = "F"

print("Categoria:", categoria)

# %%
# === CAJERO AUTOMÁTICO ===

saldo = 500000  # Saldo inicial

print("=== CAJERO AUTOMÁTICO ===")
print(f"Saldo actual: ${saldo:,}")
print()
print("¿Qué deseas hacer?")
print("1. Consultar saldo")
print("2. Retirar dinero")
print("3. Depositar dinero")

opcion = input("\nElige una opción (1/2/3): ")

if opcion == "1":
    print(f"\nTu saldo es: ${saldo:,}")

elif opcion == "2":
    monto = int(input("¿Cuánto deseas retirar? $"))
    if monto <= saldo:
        saldo = saldo - monto
        print(f"\nRetiraste: ${monto:,}")
        print(f"Nuevo saldo: ${saldo:,}")
    else:
        print("\n❌ Saldo insuficiente")

elif opcion == "3":
    monto = int(input("¿Cuánto deseas depositar? $"))
    if monto > 0:
        saldo = saldo + monto
        print(f"\nDepositaste: ${monto:,}")
        print(f"Nuevo saldo: ${saldo:,}")
    else:
        print("\n❌ El monto debe ser mayor a 0")

else:
    print("\n❌ Opción no válida")

# %% [markdown]
# ---
# ## 💪 Ejercicios
#
# ### Nivel A: Guiado

# %% [markdown]
# **Ejercicio A1:** Verificador de número positivo/negativo/cero

# %%
numero = int(input("Ingresa un número: "))

# Completa los condicionales
if numero > 0:
    print("El número es positivo")
elif ???:
    print("El número es negativo")
else:
    print("El número es cero")

# %% [markdown]
# **Ejercicio A2:** ¿Es fin de semana?

# %%
dia = input("¿Qué día es hoy? (lunes, martes, ..., domingo): ").lower()

# Completa usando 'or'
if dia == "sabado" ??? dia == "domingo":
    print("¡Es fin de semana! 🎉")
else:
    print("Es día de semana 📚")

# %% [markdown]
# **Ejercicio A3:** Verificador de contraseña

# %%
# La contraseña correcta es "python123"
contrasena_correcta = "python123"

intento = input("Ingresa la contraseña: ")

if ???:
    print("✅ Acceso concedido")
else:
    print("❌ Contraseña incorrecta")

# %% [markdown]
# ### Nivel B: Independiente

# %% [markdown]
# **Ejercicio B1:** Calculadora de tarifa de taxi
#
# Reglas:
# - Tarifa base: $5,000
# - Por cada km: $1,500
# - Si es de noche (después de las 20h): +20% al total
# - Si es festivo: +30% al total

# %%
# Pide: kilometros, hora (0-23), es_festivo (s/n)
# Calcula la tarifa aplicando los recargos correspondientes

# Tu código aquí:

# %% [markdown]
# **Ejercicio B2:** Clasificador de triángulos
#
# Pide 3 lados y determina:
# - Equilátero: 3 lados iguales
# - Isósceles: 2 lados iguales
# - Escaleno: todos diferentes

# %%
# Pide los 3 lados
# Clasifica el triángulo

# Tu código aquí:

# %% [markdown]
# **Ejercicio B3:** Sistema de descuentos por edad
#
# - Niños (0-12): 50% descuento
# - Jóvenes (13-25): 20% descuento
# - Adultos (26-59): Sin descuento
# - Adultos mayores (60+): 30% descuento

# %%
# Pide: precio del producto y edad del cliente
# Calcula y muestra: descuento aplicado y precio final

# Tu código aquí:

# %% [markdown]
# ### Nivel C: Reto Opcional 🌟

# %% [markdown]
# **Ejercicio C1:** Piedra, Papel o Tijera
#
# El usuario elige y la computadora elige aleatoriamente. Determina el ganador.

# %%
import random

opciones = ["piedra", "papel", "tijera"]
computadora = random.choice(opciones)

# Pide la elección del usuario
# Compara y determina el ganador
# Reglas: piedra > tijera, tijera > papel, papel > piedra

# Tu código aquí:

# %% [markdown]
# ---
# ## ⚠️ Errores Comunes
#
# ### Error 1: Olvidar los dos puntos (:)

# %%
# ❌ INCORRECTO
# if edad >= 18
#     print("Mayor de edad")

# ✅ CORRECTO
edad = 18
if edad >= 18:
    print("Mayor de edad")

# %% [markdown]
# ### Error 2: Indentación incorrecta

# %%
# ❌ INCORRECTO
# if edad >= 18:
# print("Mayor de edad")  # IndentationError!

# ✅ CORRECTO
edad = 18
if edad >= 18:
    print("Mayor de edad")  # 4 espacios de indentación

# %% [markdown]
# ### Error 3: Usar = en lugar de ==

# %%
# ❌ INCORRECTO
# if nombre = "Ana":  # SyntaxError!

# ✅ CORRECTO
nombre = "Ana"
if nombre == "Ana":  # Usa == para comparar
    print("Hola Ana")

# %% [markdown]
# ### Error 4: Orden incorrecto de elif

# %% [markdown]
# ### Error 5: Rangos en orden incorrecto
#
# Siempre evalua primero el rango mas alto; si no, nunca llegaras a las otras opciones.

# %%
# ❌ INCORRECTO - El orden importa
nota = 95
if nota >= 60:
    print("Aprobado")  # Se ejecuta esto y se ignora el resto
elif nota >= 90:
    print("Excelente")  # Nunca llega aquí

print()

# ✅ CORRECTO - Condiciones más restrictivas primero
nota = 95
if nota >= 90:
    print("Excelente")
elif nota >= 60:
    print("Aprobado")

# %% [markdown]
# ---
# ## 📝 Mini-Quiz de Cierre
#
# **1.** ¿Qué imprime este código?
# ```python
# x = 5
# if x > 10:
#     print("A")
# elif x > 3:
#     print("B")
# else:
#     print("C")
# ```
# - a) A
# - b) B
# - c) C
#
# **2.** ¿Qué palabra clave se usa para "de lo contrario, si..."?
# - a) else if
# - b) elseif
# - c) elif
#
# **3.** ¿Qué imprime?
# ```python
# if True and False:
#     print("Sí")
# else:
#     print("No")
# ```
# - a) Sí
# - b) No
# - c) Error
#
# **4.** ¿Cuál es el error?
# ```python
# if edad >= 18
#     print("Mayor")
# ```
# - a) Falta indentación
# - b) Faltan los dos puntos (:)
# - c) Falta else
#
# **5.** ¿Qué imprime `if not False: print("Hola")`?
# - a) Nada
# - b) Hola
# - c) Error

# %% [markdown]
# <details>
# <summary>👀 Ver respuestas</summary>
#
# 1. **b) B** - x=5 no es >10, pero sí >3
# 2. **c) elif** - Es la forma de Python
# 3. **b) No** - True AND False = False
# 4. **b) Faltan los dos puntos** - Debe ser `if edad >= 18:`
# 5. **b) Hola** - not False = True
#
# </details>

# %% [markdown]
# ---
# ## 🎮 Actividades Interactivas
#
# ### 🧠 Actividad: Think-Pair-Share
# **Pregunta:** ¿Por qué la indentación (sangría) es obligatoria en Python? Imagina un mundo sin indentación: ¿Cómo sabríamos qué código pertenece al `if`?
#
# ### 🐞 Debugging en Vivo
# Encuentra los errores de lógica o sintaxis:

# %%
edad = 15

# Error 1: Sintaxis
# if edad >= 18
#     print("Mayor")

# Error 2: Lógica (Orden incorrecto de rangos)
nota = 85
if nota > 60:
    print("Ganaste")
elif nota > 80:
    print("Excelente") # ¿Llegará alguna vez aquí?

# Error 3: Confusión = vs ==
# if edad = 18:
#    print("Tienes 18")

# %% [markdown]
# ### 🚀 Proyecto Colaborativo: Sistema Experto de Recomendación
# En parejas, crea un programa que recomiende una película basándose en:
# 1. Género (Acción, Comedia, Drama)
# 2. Duración preferida (Corta, Larga)
# 3. Edad del espectador
#
# Usa condicionales anidados o `elif` para dar una respuesta personalizada.

# %%
# Tu código para el Sistema Experto:

# %% [markdown]
# ## 🎯 Resumen de la Sesión
#
# Hoy aprendiste:
# 1. **`if`** ejecuta código si la condición es True
# 2. **`else`** ejecuta código si la condición es False
# 3. **`elif`** permite verificar múltiples condiciones
# 4. **Indentación** es obligatoria (4 espacios)
# 5. Puedes combinar con **`and`**, **`or`**, **`not`**
#
# ---
#
# ## 🌐 ¡Practica en la Web!
#
# ¿Quieres ver cómo funcionan los condicionales en JavaScript?
#
# **Abre la plantilla web de S04** en tu navegador o en [CodePen.io](https://codepen.io/pen):
#
# ```
# estudiantes/templates/web_sessions/s04/
# ```
#
# Encontrarás ejercicios interactivos para practicar:
# - 🎂 Verificador de Edad - if/else simple
# - 📊 Clasificador de Notas - Múltiples condiciones
# - 🎉 ¿Es Fin de Semana? - Usando OR (`||`)
# - 🏧 Cajero Automático - Condicionales anidados con estado
# - 💰 Calculadora de Descuentos - Rangos de edad
# - 🔐 Verificador de Contraseña - Comparación de strings
#
# **¡Los condicionales en JavaScript son casi idénticos!** Solo cambia:
# - `elif` → `else if`
# - `and` → `&&`
# - `or` → `||`
# - `not` → `!`
# - `==` → `===` (comparación estricta)
#
# ---
#
# ## ➡️ Próxima Sesión
# **Sesión 6: Bucles (for y while)**
#
# ¡Aprenderás a repetir código automáticamente!
#
# ---
# *📋 Después de esta sesión viene la **Evaluación 1** (Nota 1)*

# %% [markdown]
# ---
# ## 🌐 Sección Web (S04) - Condicionales en JavaScript
#
# ---
#
# ## 🚦 Condicionales JavaScript vs Python
#
# ¡Los condicionales en JavaScript son **MUY SIMILARES** a Python!
#
# ### if/else - CASI IGUALES
#
# **Python:**
# ```python
# if edad >= 18:
#     print("Eres mayor de edad")
# else:
#     print("Eres menor de edad")
# ```
#
# **JavaScript:**
# ```javascript
# if (edad >= 18) {
#     console.log("Eres mayor de edad");
# } else {
#     console.log("Eres menor de edad");
# }
# ```
#
# **Diferencias clave:**
# 1. JavaScript usa `{ }` en lugar de indentación
# 2. JavaScript requiere paréntesis `( )` alrededor de la condición
# 3. La indentación en JS es opcional (pero recomendada para legibilidad)
#
# ### if/elif/else - elif → else if
#
# **Python:**
# ```python
# if nota >= 90:
#     print("A")
# elif nota >= 80:
#     print("B")
# elif nota >= 70:
#     print("C")
# else:
#     print("F")
# ```
#
# **JavaScript:**
# ```javascript
# if (nota >= 90) {
#     console.log("A");
# } else if (nota >= 80) {  // ← "elif" se convierte en "else if"
#     console.log("B");
# } else if (nota >= 70) {
#     console.log("C");
# } else {
#     console.log("F");
# }
# ```
#
# ### Operadores Lógicos - Diferentes Símbolos
#
# | Python | JavaScript | Ejemplo |
# |--------|------------|---------|
# | `and` | `&&` | `edad >= 18 && tieneLicencia` |
# | `or` | `||` | `esEstudiante \|\| esProfesor` |
# | `not` | `!` | `!estaLloviendo` |
#
# ### Comparaciones - ¡Usa SIEMPRE ===!
#
# | Python | JavaScript |
# |--------|------------|
# | `==` (igual) | `===` (igual estricto) |
# | `!=` (diferente) | `!==` (diferente estricto) |
#
# **⚠️ IMPORTANTE:** En JavaScript siempre usa `===` y `!==`
# ```javascript
# // ❌ MAL: == puede hacer conversiones raras
# 5 == "5"   // true (JS convierte string a number)
#
# // ✅ BIEN: === no convierte
# 5 === "5"  // false (number !== string)
# ```
#
# ---
#
# ## 📝 Comparación de Condicionales
#
# ### Python
# ```python
# edad = 17
# tiene_licencia = False
#
# if edad >= 18 and tiene_licencia:
#     print("Puedes conducir")
# elif edad >= 18:
#     print("Necesitas licencia")
# else:
#     print("Eres muy joven")
# ```
#
# ### JavaScript
# ```javascript
# let edad = 17;
# let tieneLicencia = false;
#
# if (edad >= 18 && tieneLicencia) {
#     console.log("Puedes conducir");
# } else if (edad >= 18) {
#     console.log("Necesitas licencia");
# } else {
#     console.log("Eres muy joven");
# }
# ```
#
# ---
#
# ## 🎯 Ejercicios Web S04
#
# La plantilla de S04 incluye estos ejercicios:
#
# 1. **Verificador de Edad** - if/else simple
# 2. **Clasificador de Notas** - if/else if/else con múltiples rangos
# 3. **Verificador de Fin de Semana** - Usando `||` (OR)
# 4. **Cajero Automático** - Condicionales anidados
# 5. **Calculadora de Descuentos** - Rangos de edad
# 6. **Verificador de Contraseña** - if/else con comparación de strings
#
# ---
#
# ## 🔗 Resumen de Equivalencias
#
# | Concepto | Python | JavaScript |
# |-----------|--------|------------|
# | Si | `if condicion:` | `if (condicion) {` |
# | Si no | `else:` | `else {` |
# | Si no, si | `elif condicion:` | `else if (condicion) {` |
# | Fin del bloque | Indentación | `}` |
# | Y | `and` | `&&` |
# | O | `or` | `||` |
# | No | `not` | `!` |
# | Igual | `==` | `===` |
# | Diferente | `!=` | `!==` |
#
# ---
#
# **¿Listo?** Abre la plantilla de S04:
#
# ### 🚀 ¡Hora de practicar en la Web!
# ¡Toma decisiones en tu página web!
#
# **Instrucciones:**
# 1. Ve a la carpeta: `estudiantes/templates/web_sessions/s04/`
# 2. Abre **`index.html`** en tu navegador.
# 3. Interactúa con el Verificador de Edad, el Cajero Automático y el Clasificador de Notas.
#
# - `estudiantes/templates/web_sessions/s04/`
