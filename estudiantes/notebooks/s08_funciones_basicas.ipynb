# %% [markdown]
# # Sesión 8: Funciones Básicas 🔧
#
# **Curso:** Estud-IA Programación G57
# **Docente:** Eldigardo Camacho
# **Duración:** ~3 horas

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/heldigard/estudia-programacion-g57/blob/master/estudiantes/notebooks/s08_funciones_basicas.ipynb)

# %% [markdown]
# ---
# ## ✅ Checklist de Apertura
#
# Antes de empezar, verifica:
# - [ ] Sé usar listas y bucles
# - [ ] Entiendo la indentación en Python
# - [ ] He usado funciones como print(), len(), input()

# %% [markdown]
# ---
# ## 🎯 Objetivos de la Sesión
#
# Al final de esta sesión, podrás:
# 1. Entender **qué es una función** y por qué son útiles
# 2. **Crear funciones** con `def`
# 3. Usar **parámetros** para pasar datos a funciones
# 4. Escribir **docstrings** para documentar funciones
# 5. **Llamar** funciones desde diferentes partes del código

# %% [markdown]
# ---
# ## 📚 Conceptos Clave
#
# ### ¿Qué es una Función?
# Una función es un **bloque de código reutilizable** que realiza una tarea específica. Es como una receta:
# - Tiene un nombre
# - Puede recibir ingredientes (parámetros)
# - Ejecuta pasos específicos
# - Puede devolver un resultado
#
# ### ¿Por qué usar funciones?
# 1. **Reutilización:** Escribe una vez, usa muchas veces
# 2. **Organización:** Código más limpio y estructurado
# 3. **Mantenimiento:** Cambias en un solo lugar
# 4. **Legibilidad:** El código es más fácil de entender

# %% [markdown]
# ---
# ## 🎬 Ejemplo Guiado: Tu Primera Función
#
# ### Paso 1: Función sin parámetros

# %%
# Sintaxis básica:
# def nombre_funcion():
#     código de la función

def saludar():
    print("¡Hola!")
    print("Bienvenido al curso de Python")

# Definir la función NO la ejecuta
# Para ejecutarla, la "llamamos":
saludar()

# %%
# Puedes llamar una función las veces que quieras
print("Primera llamada:")
saludar()

print("\nSegunda llamada:")
saludar()

print("\nTercera llamada:")
saludar()

# %% [markdown]
# ### Paso 2: Función con parámetros

# %%
# Los parámetros son "variables" que la función recibe
def saludar_persona(nombre):
    print(f"¡Hola, {nombre}!")
    print(f"Bienvenido/a al curso de Python")

# Llamamos la función con diferentes valores
saludar_persona("Ana")
print()
saludar_persona("Carlos")
print()
saludar_persona("María")

# %%
# Función con múltiples parámetros
def presentar(nombre, edad, ciudad):
    print(f"Me llamo {nombre}")
    print(f"Tengo {edad} años")
    print(f"Vivo en {ciudad}")

presentar("Juan", 25, "Bogotá")
print()
presentar("Laura", 30, "Medellín")

# %% [markdown]
# ### Paso 3: Parámetros por nombre (keyword arguments)

# %%
# Puedes pasar los parámetros por nombre (en cualquier orden)
def crear_perfil(nombre, edad, profesion):
    print(f"Nombre: {nombre}")
    print(f"Edad: {edad}")
    print(f"Profesión: {profesion}")

# Por posición (orden importa)
print("Por posición:")
crear_perfil("Ana", 28, "Ingeniera")

print()

# Por nombre (orden no importa)
print("Por nombre:")
crear_perfil(profesion="Diseñador", nombre="Pedro", edad=32)

# %% [markdown]
# ### Paso 4: Parámetros con valores por defecto

# %%
# Los valores por defecto se usan si no se proporciona un valor
def saludar_formal(nombre, titulo="Sr./Sra."):
    print(f"Buenos días, {titulo} {nombre}")

# Sin especificar título (usa el valor por defecto)
saludar_formal("García")

# Especificando título
saludar_formal("López", "Dr.")
saludar_formal("Martínez", "Ing.")

# %%
# Ejemplo más completo: calculadora de propinas
def calcular_propina(cuenta, porcentaje=10):
    propina = cuenta * porcentaje / 100
    total = cuenta + propina
    print(f"Cuenta: ${cuenta:,}")
    print(f"Propina ({porcentaje}%): ${propina:,}")
    print(f"Total: ${total:,}")

print("Con propina por defecto (10%):")
calcular_propina(50000)

print("\nCon propina del 15%:")
calcular_propina(50000, 15)

print("\nCon propina del 20%:")
calcular_propina(50000, porcentaje=20)

# %% [markdown]
# ### Paso 5: Docstrings - Documentando funciones

# %%
def calcular_area_rectangulo(base, altura):
    """
    Calcula el área de un rectángulo.
    
    Parámetros:
        base: El ancho del rectángulo
        altura: La altura del rectángulo
    
    Ejemplo:
        calcular_area_rectangulo(5, 3)  # Imprime: Área = 15
    """
    area = base * altura
    print(f"Área = {area}")

# Usar la función
calcular_area_rectangulo(5, 3)

# Ver la documentación
print("\nDocumentación de la función:")
help(calcular_area_rectangulo)

# %% [markdown]
# ---
# ## 🎬 Funciones Prácticas
#
# ### Ejemplo: Validador de edad

# %%
def verificar_edad(edad, edad_minima=18):
    """
    Verifica si una persona cumple con la edad mínima.
    """
    if edad >= edad_minima:
        print(f"✅ Acceso permitido (edad: {edad})")
    else:
        print(f"❌ Acceso denegado. Requiere {edad_minima} años (tienes {edad})")

verificar_edad(25)
verificar_edad(15)
verificar_edad(20, 21)  # Para entrar a un bar en USA

# %% [markdown]
# ### Ejemplo: Imprimir tabla de multiplicar

# %%
def tabla_multiplicar(numero, hasta=10):
    """
    Imprime la tabla de multiplicar de un número.
    """
    print(f"=== Tabla del {numero} ===")
    for i in range(1, hasta + 1):
        print(f"{numero} x {i} = {numero * i}")

tabla_multiplicar(7)

# %%
# Con parámetro personalizado
tabla_multiplicar(5, hasta=5)

# %% [markdown]
# ### Ejemplo: Dibujar figuras

# %%
def dibujar_linea(caracter="-", longitud=20):
    """Dibuja una línea horizontal."""
    print(caracter * longitud)

def dibujar_rectangulo(ancho=10, alto=5, caracter="*"):
    """Dibuja un rectángulo con el caracter especificado."""
    for fila in range(alto):
        print(caracter * ancho)

dibujar_linea()
print()
dibujar_linea("=", 30)
print()
dibujar_rectangulo(15, 4, "#")

# %% [markdown]
# ---
# ## ⭐ Actividad Estrella: Generador de Reportes

# %% [markdown]
# ---
# ## Actividad Extra (10-15 min): Mini biblioteca de conversiones
#
# Objetivo: crear varias funciones reutilizables.
#
# Pasos sugeridos:
# 1. Crea 3 funciones de conversion
# 2. Usa parametros por defecto en una funcion
# 3. Prueba cada funcion con datos reales

# %%
# === MINI-PROYECTO: BIBLIOTECA DE CONVERSIONES ===

def km_a_millas(km):
    return km * 0.621371


def c_a_f(c):
    return c * 9/5 + 32


def aplicar_descuento(precio, pct=0):
    return precio * (1 - pct/100)

print(km_a_millas(10))
print(c_a_f(20))
print(aplicar_descuento(100000, 15))

# %%
# === GENERADOR DE REPORTES DE NOTAS ===

def imprimir_encabezado(titulo):
    """Imprime un encabezado formateado."""
    print("=" * 40)
    print(f"  {titulo.upper()}")
    print("=" * 40)

def imprimir_separador():
    """Imprime una línea separadora."""
    print("-" * 40)

def mostrar_nota(estudiante, nota):
    """Muestra la nota de un estudiante con su estado."""
    if nota >= 60:
        estado = "✅ Aprobado"
    else:
        estado = "❌ Reprobado"
    print(f"  {estudiante}: {nota} - {estado}")

def generar_reporte(titulo, estudiantes, notas):
    """Genera un reporte completo de notas."""
    imprimir_encabezado(titulo)
    
    for i in range(len(estudiantes)):
        mostrar_nota(estudiantes[i], notas[i])
    
    imprimir_separador()
    promedio = sum(notas) / len(notas)
    print(f"  Promedio del grupo: {promedio:.1f}")
    print(f"  Nota más alta: {max(notas)}")
    print(f"  Nota más baja: {min(notas)}")
    imprimir_separador()

# Datos de prueba
nombres = ["Ana", "Carlos", "María", "Pedro", "Lucía"]
calificaciones = [85, 72, 90, 55, 78]

# Generar el reporte
generar_reporte("Reporte de Matemáticas", nombres, calificaciones)

# %% [markdown]
# ---
# ## 💪 Ejercicios
#
# ### Nivel A: Guiado

# %% [markdown]
# **Ejercicio A1:** Crea una función que salude

# %%
# Crea una función llamada 'bienvenida' que reciba un nombre
# e imprima "¡Bienvenido/a, [nombre]!"

def bienvenida(???):
    print(f"¡Bienvenido/a, {???}!")

# Prueba la función
bienvenida("María")
bienvenida("Juan")

# %% [markdown]
# **Ejercicio A2:** Función con valor por defecto

# %%
# Crea una función 'despedirse' que reciba un nombre y un mensaje
# El mensaje debe tener valor por defecto: "¡Hasta luego!"

def despedirse(nombre, mensaje=???):
    print(f"{nombre}, {mensaje}")

# Prueba
despedirse("Ana")                      # Usa mensaje por defecto
despedirse("Carlos", "¡Nos vemos!")   # Mensaje personalizado

# %% [markdown]
# **Ejercicio A3:** Añade un docstring

# %%
# Añade un docstring a esta función explicando qué hace

def calcular_descuento(precio, porcentaje):
    ???  # Añade el docstring aquí
    descuento = precio * porcentaje / 100
    precio_final = precio - descuento
    print(f"Precio original: ${precio}")
    print(f"Descuento ({porcentaje}%): ${descuento}")
    print(f"Precio final: ${precio_final}")

calcular_descuento(100000, 15)

# %% [markdown]
# ### Nivel B: Independiente

# %% [markdown]
# **Ejercicio B1:** Función para calcular área de círculo
#
# Crea una función que reciba el radio y calcule el área (π * r²)

# %%
# Tu código aquí:

# %% [markdown]
# **Ejercicio B2:** Función para verificar si un número es par
#
# Crea una función que reciba un número e imprima si es par o impar.

# %%
# Tu código aquí:

# %% [markdown]
# **Ejercicio B3:** Función para mostrar estadísticas de una lista
#
# Crea una función que reciba una lista de números e imprima: cantidad, suma, promedio, mínimo y máximo.

# %%
# Tu código aquí:

# %% [markdown]
# ### Nivel C: Reto Opcional 🌟

# %% [markdown]
# **Ejercicio C1:** Menú de restaurante
#
# Crea varias funciones para:
# - Mostrar el menú (lista de productos con precios)
# - Agregar producto al pedido
# - Mostrar el total del pedido

# %%
# Tu código aquí:

# %% [markdown]
# ---
# ## ⚠️ Errores Comunes
#
# ### Error 1: Olvidar los paréntesis al llamar la función

# %%
def saludar():
    print("¡Hola!")

# ❌ INCORRECTO - Esto no ejecuta la función
print("Sin paréntesis:", saludar)  # Muestra la referencia a la función

# ✅ CORRECTO - Con paréntesis
print("Con paréntesis:")
saludar()

# %% [markdown]
# ### Error 2: Parámetros en orden incorrecto

# %%
def mostrar_info(nombre, edad):
    print(f"{nombre} tiene {edad} años")

# ❌ INCORRECTO - Orden equivocado
mostrar_info(25, "Ana")  # "25 tiene Ana años" - ¡No tiene sentido!

# ✅ CORRECTO
mostrar_info("Ana", 25)
# O usando nombres:
mostrar_info(edad=25, nombre="Ana")

# %% [markdown]
# ### Error 3: Parámetros con valor por defecto antes de los obligatorios

# %% [markdown]
# ### Error 4: No usar return cuando necesitas el resultado
#
# Si tu funcion no retorna, el valor resultante sera None.

# %%
# ❌ INCORRECTO - SyntaxError
# def saludar(saludo="Hola", nombre):
#     print(f"{saludo}, {nombre}")

# ✅ CORRECTO - Parámetros con valor por defecto al final
def saludar(nombre, saludo="Hola"):
    print(f"{saludo}, {nombre}")

saludar("Ana")
saludar("Carlos", "Buenos días")

# %% [markdown]
# ---
# ## 📝 Mini-Quiz de Cierre
#
# **1.** ¿Qué palabra clave se usa para definir una función?
# - a) function
# - b) def
# - c) func
#
# **2.** ¿Cómo se llama el texto entre `"""` al inicio de una función?
# - a) Comentario
# - b) Docstring
# - c) String literal
#
# **3.** ¿Qué imprime este código?
# ```python
# def saludar(nombre="Mundo"):
#     print(f"Hola, {nombre}")
#
# saludar()
# ```
# - a) Error
# - b) Hola, nombre
# - c) Hola, Mundo
#
# **4.** ¿Qué pasa si defines una función pero nunca la llamas?
# - a) Error
# - b) Se ejecuta automáticamente
# - c) No pasa nada, no se ejecuta
#
# **5.** ¿Cuál es la forma correcta de llamar una función?
# - a) `mi_funcion`
# - b) `mi_funcion()`
# - c) `call mi_funcion`

# %% [markdown]
# <details>
# <summary>👀 Ver respuestas</summary>
#
# 1. **b) def** - Es la palabra clave de Python
# 2. **b) Docstring** - Documentación de la función
# 3. **c) Hola, Mundo** - Usa el valor por defecto
# 4. **c) No pasa nada** - Se define pero no se ejecuta
# 5. **b) mi_funcion()** - Los paréntesis son obligatorios
#
# </details>

# %% [markdown]
# ---
# ## 🎮 Actividades Interactivas
#
# ### 🧠 Actividad: Think-Pair-Share
# **Pregunta:** ¿Por qué crear una función si puedo simplemente copiar y pegar el código 5 veces? ¿Qué pasa si encuentro un error en ese código copiado?
#
# ### 🐞 Debugging en Vivo
# Estos códigos tienen errores comunes con funciones:

# %%
def saludar(nombre):
    print(f"Hola {nombre}")

# Error 1: Olvidar paréntesis
# saludar "Ana"

# Error 2: Scope (Alcance)
def crear_secreto():
    secreto = 42

# print(secreto) # ¿Por qué falla esto?

# Error 3: Argumentos faltantes
# saludar() # Falta el nombre

# %% [markdown]
# ### 🚀 Proyecto Colaborativo: Bot Saludador Personalizable
# Crea una función `bot_saludo(nombre, idioma, momento_dia)` que imprima un saludo diferente según los parámetros.
# Ejemplo: `bot_saludo("Juan", "EN", "mañana")` -> "Good morning, Juan!"

# %%
# Tu código aquí:

# %% [markdown]
# ---
# ## 🎯 Resumen de la Sesión
#
# Hoy aprendiste:
# 1. **`def`** define una función
# 2. **Parámetros** reciben datos: `def funcion(param1, param2)`
# 3. **Valores por defecto**: `def funcion(param="valor")`
# 4. **Docstrings** documentan: `"""Descripción"""`
# 5. **Llamar** con paréntesis: `funcion()` o `funcion(arg1, arg2)`
#
# ---
#
# ## ➡️ Próxima Sesión
# **Sesión 9: Funciones con Return**
#
# ¡Aprenderás a que las funciones devuelvan valores!
#
# ---
# *Las funciones son el corazón de la programación modular 💪*

# %% [markdown]
# ## 🌐 Sección Web (S08) — Funciones básicas
#
# **Objetivo:** separar cálculo de UI.
#
# ```html
# <input id="monto" type="number" placeholder="Monto" />
# <input id="propina" type="number" placeholder="% Propina" />
# <button onclick="calcular()">Calcular</button>
# <p id="salida"></p>
# ```
#
# ```javascript
# function totalConPropina(monto, porcentaje) {
#   return monto + (monto * porcentaje / 100);
# }
#
# function calcular() {
#   const monto = Number(document.getElementById("monto").value);
#   const porcentaje = Number(document.getElementById("propina").value);
#   const total = totalConPropina(monto, porcentaje);
#   document.getElementById("salida").textContent = `Total: ${total}`;
# }
# ```
#
# **Puente con Python:** funciones puras reutilizables.
